# %%
import sympy

# %%
sympy.init_printing(use_latex="mathjax")

# %%
x= sympy.Symbol('x')

# %%
f = 5*x**2 +2*x + 8
sympy.diff(x)
# Out:
# 1

# %%
f1 = sympy.simplify(sympy.diff(f))
f1
# Out:
# 10⋅x + 2

# %%
f1.subs(x, 1.0).evalf()
# Out:
# 12.0000000000000

# %%
from sympy import Symbol, Derivative # import the packages as the these are object
x = Symbol("x")
d = Derivative (f,x) # this needs to happen
d.doit() # function to actually run the function
# Out:
# 10⋅x + 2

# %%
x = sympy.Symbol("x")
f = (2 + 5*x) - (1/((x-2)**2))
sympy.integrate(2 + 5*x - (1/((x-2)**2)),(x,0,4))
# Out:
# -∞

# %%
def f(x):
    return x ** 3 - 3 * x ** 2 + x + 6

# %%
import scipy as scp
i = scp.integrate.quad(f,0,2)
print(i)
print(i[0])
# Out:
# (10.0, 1.1102230246251565e-13)
# 10.0

# %%
x = sympy.symbols('x')
f = x ** 3 - 3 * x ** 2 + x + 6
f
F = sympy.integrate(f)
F
# Out:
#  4         2
# x     3   x
# ── - x  + ── + 6⋅x
# 4         2

# %%
(F.subs(x, 2) - F.subs(x, 0)).evalf()
# Out:
# 10.0000000000000
